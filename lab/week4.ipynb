# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\krish\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#predict whether a passenger survived the titanic
objective = "Classification: Survived (Yes/No)"
success_criteria = "Accuracy > 80%"
constraints = "Limited features, missing values, imbalanced classes"
print("Objective: ", objective)
print("Success Criteria:", success_criteria)
print("Constraints:", constraints)
# Out:
# Objective:  Classification: Survived (Yes/No)
# Success Criteria: Accuracy > 80%
# Constraints: Limited features, missing values, imbalanced classes

# %%
#Data Collection
#Load Dataset
import seaborn as sns
df = sns.load_dataset("titanic")
print("Data Shape:", df.shape)
print(df.head())
# Out:
# Data Shape: (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Data cleaning and preprocessing
#handle mising values

import seaborn as sns
import pandas as pd
df = sns.load_dataset("titanic")
df['age'].fillna(df['age'].median(), inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
df.drop_duplicates(inplace = True)
df = pd.get_dummies(df, columns=['sex', 'class', 'embarked'], drop_first=True)
df['family_size'] = df['sibsp'] + df['parch']
print(df.head)
# Out:
# <bound method NDFrame.head of      survived  pclass   age  sibsp  parch     fare    who  adult_male deck  \
# 0           0       3  22.0      1      0   7.2500    man        True  NaN
# 1           1       1  38.0      1      0  71.2833  woman       False    C
# 2           1       3  26.0      0      0   7.9250  woman       False  NaN
# 3           1       1  35.0      1      0  53.1000  woman       False    C
# 4           0       3  35.0      0      0   8.0500    man        True  NaN
# ..        ...     ...   ...    ...    ...      ...    ...         ...  ...
# 885         0       3  39.0      0      5  29.1250  woman       False  NaN
# 887         1       1  19.0      0      0  30.0000  woman       False    B
# 888         0       3  28.0      1      2  23.4500  woman       False  NaN
# 889         1       1  26.0      0      0  30.0000    man        True    C
# 890         0       3  32.0      0      0   7.7500    man        True  NaN
#
#      embark_town alive  alone  sex_male  class_Second  class_Third  \
# 0    Southampton    no  False      True         False         True
# 1      Cherbourg   yes  False     False         False        False
# 2    Southampton   yes   True     False         False         True
# 3    Southampton   yes  False     False         False        False
# 4    Southampton    no   True      True         False         True
# ..           ...   ...    ...       ...           ...          ...
# 885   Queenstown    no  False     False         False         True
# 887  Southampton   yes   True     False         False        False
# 888  Southampton    no  False     False         False         True
# 889    Cherbourg   yes   True      True         False        False
# 890   Queenstown    no   True      True         False         True
#
#      embarked_Q  embarked_S  family_size
# 0         False        True            1
# 1         False       False            1
# 2         False        True            0
# 3         False        True            1
# 4         False        True            0
# ..          ...         ...          ...
# 885        True       False            5
# 887       False        True            0
# 888       False        True            3
# 889       False       False            0
# 890        True       False            0
#
# [781 rows x 18 columns]>
# C:\Users\krish\AppData\Local\Temp\ipykernel_127988\2188289716.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)
# C:\Users\krish\AppData\Local\Temp\ipykernel_127988\2188289716.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset("titanic")
sns.histplot(df['age'], bins=20,kde=True)
plt.title("Age Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset("tips")
sns.histplot(df['size'], bins=10,kde=True)
plt.title("Age Distribution")
plt.show()

# %%
#Correlation matrix graph - heatmap
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)
print(corr)
sns.heatmap(corr, annot = True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
